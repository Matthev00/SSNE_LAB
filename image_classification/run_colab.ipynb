# %%
# !git clone https://github.com/Matthev00/SSNE_LAB.git && %cd SSNE_LAB/image_classification
# Out:
# Cloning into 'SSNE_LAB'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (174/174), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 174 (delta 99), reused 139 (delta 64), pack-reused 0 (from 0)
# Receiving objects: 100% (174/174), 681.02 KiB | 24.32 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# /bin/bash: line 1: fg: no job control

# %%
# %cd SSNE_LAB/image_classification
# Out:
# /content/SSNE_LAB/image_classification

# %%
# !pwd
# Out:
# /content/SSNE_LAB/image_classification

# %%
# !ls
# Out:
# data.py    main.py    Ostaszewski_Mateusz_Sadowski_Michał.ipynb  test_models.py
# engine.py  models.py  sweep_runner.py

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !cp -r /content/drive/MyDrive/SSNE/data/train.zip /content/train.zip

# %%
# %%capture
# !cd /content/ && unzip /content/train.zip

# %%
# !mkdir /content/SSNE_LAB/image_classification/data/
# Out:
# mkdir: cannot create directory ‘/content/SSNE_LAB/image_classification/data/’: File exists

# %%
# !mv /content/train/ /content/SSNE_LAB/image_classification/data/

# %%
# !ls data/train
# Out:
# acoustic  beetle   bread   corn		elephant  gauge     monkey  pot      spider  tomato
# antenna   bicycle  bridge  crab		fish	  hammer    motor   printer  spoon   towel
# bacteria  birch    camera  crocodilian	flower	  icecream  nest    saw      squash  truck
# battery   bird	   carbon  echinoderm	frog	  kangaroo  palm    snake    swine   turtle
# bean	  bomb	   cat	   egg		fungus	  memorial  pizza   spice    tea     worm

# %%
# !python sweep_runner.py
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: u6rxfl3g
# Sweep URL: https://wandb.ai/MY_EXPERIMENTS/image-classification/sweeps/u6rxfl3g
# wandb: Agent Starting Run: k80yj550 with config:
# wandb: 	batch_size: 16
# wandb: 	data_percent: 0.2
# wandb: 	dropout: 0.5
# wandb: 	epochs: 20
# wandb: 	hidden_size: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	model_name: CNN_BN
# wandb: 	patience: 2
# wandb: 	scheduler_factor: 0.5
# wandb: 	weight_decay: 0.001
# wandb: Currently logged in as: michall00 (MY_EXPERIMENTS) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/SSNE_LAB/image_classification/wandb/run-20250406_110716-k80yj550
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run true-sweep-1
# ...

# %%
2
